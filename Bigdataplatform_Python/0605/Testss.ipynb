# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 

# 한글문제 해결처리 
################################################################
from matplotlib import font_manager, rc
import platform
plt.rcParams['axes.unicode_minus'] = False
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')
################################################################

# 다음의 결과를 출력하시오. 성별 기준 검사건수 출력


df = pd.read_excel("sidata.xlsx")
df
# Out:
#                   검역일시        검역소  국적 성별 승객승무원구분 검사결과
# 0     2019-01-01 04:21  국립인천공항검역소  한국  여      승객   양성
# 1     2019-01-01 04:21  국립인천공항검역소  한국  여      승객   양성
# 2     2019-01-01 06:10    국립김해검역소  한국  남      승객   양성
# 3     2019-01-01 06:25  국립인천공항검역소  한국  여      승객   양성
# 4     2019-01-01 06:25  국립인천공항검역소  한국  남      승객   양성
# ...                ...        ...  .. ..     ...  ...
# 1864  2019-12-31 04:30  국립인천공항검역소  한국  여      승객   양성
# 1865  2019-12-31 04:30  국립인천공항검역소  한국  남      승객   양성
# 1866  2019-12-31 07:10  국립인천공항검역소  한국  여      승객   양성
# 1867  2019-12-31 11:53  국립인천공항검역소  한국  남      승객   양성
# 1868  2019-12-31 13:15    국립제주검역소  중국  여      승객   음성
#
# [1869 rows x 6 columns]

# %%
# wmen = da['성별'] == '여'
# men = da['성별'] == '남'
# testcase = da['검사결과']
# case = testcase.count()
# sex = [wmen,men]
# fig= plt.figure(figsize=(9,4))
# plt.bar(sex[0],case, color ='lightblue')
# plt.bar(sex[1],case, color ='c')
# plt.show()

df2 = df.loc[:,['성별', '검사결과']]
df3 = df2.groupby(by ='성별').count().reset_index()
df3.columns = ['성별','검사건수']
plt.bar(df3['성별'],df3['검사건수'])
# Out:
# <BarContainer object of 2 artists>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
# 한글문제 해결처리 
################################################################
from matplotlib import font_manager, rc
import platform
plt.rcParams['axes.unicode_minus'] = False
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')
################################################################
df = pd.read_excel("sidata.xlsx")
df2 = df.loc[:,['성별','검사결과','국적']]
df3 = df2.groupby(by=['성별','검사결과']).count()
df4 = df3.reset_index()

df4.columns=['성별','검사결과','유무']
ind = ['남','여']
df4

men = df4.iloc[:2,2]
women = df4.iloc[2:,2]
ind = ['양성', '음성']
plt.bar(ind, men, color='gray')
plt.bar(ind, women, bottom=men, color= 'lightblue')
plt.legend(labels=['남','여'])
plt.show()
