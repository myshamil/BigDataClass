# %%
import numpy as np 
import pandas as pd 

df =pd.read_csv('/python_Pjt/data2/gapminder.tsv',sep='\t')
df.head() #데이터 확인
df.tail()
type(df) #타입 확인 
df.columns
df.dtypes
# df.info() #r에서 str함수
cdf = df['country']
cdf.head()
type(cdf) #시리즈임을 볼 수 있다. 

df.iloc[-1]
#1, 100, 1000번 행 동시 추출
df.loc[[1,100,1000]] #대괄호로 한 번 더 묶으면 하나의 요소로 인식하게 돼서 한번에 뽑을 수 있음 

df.loc[:,['year','pop']]
df.iloc[:,[2,4,-1]]
df.iloc[:,0:6:2] #0번부터 6번까지 2개씩 증가
#df의 1, 10, 100 번 행의 2,4, 열을 추출
df.iloc[[1,10,100],[2,4]]
# Out:
#      year       pop
# 1    1957   9240934
# 10   2002  25268405
# 100  1972  70759295

# %%
df
#lifeExp열을 연도별로 그룹화 하여 평균 계산
df.groupby("year")['lifeExp'].mean()
#lifeExp, gdpPercap 열의 평균값을 연도, 대륙별로 그룹화해서 계산
df.groupby(["year","continent"])[['lifeExp','gdpPercap']].mean()
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
#      Americas   60.410920   5668.253496
#      Asia       54.663640   5971.173374
#      Europe     69.737600  10143.823757
#      Oceania    71.310000  14495.021790
# 1972 Africa     47.450942   2339.615674
#      Americas   62.394920   6491.334139
# ...

# %%
df
#대륙별 국가의 개수
df.groupby("continent")['country'].nunique()

import seaborn as sns 
anscombe = sns.load_dataset("anscombe")
anscombe.describe()#기술통계 
#통계치로만 데이터를 해석하지 않기
anscombe #dataset 단위로 x 및 y의 평균을 출력
anscombe.groupby('dataset')[['x','y']].mean()

import matplotlib.pyplot as plt 
d1 = anscombe[anscombe['dataset']=='I']
d2 = anscombe[anscombe['dataset']=='II']
d3 = anscombe[anscombe['dataset']=='III']
d4 = anscombe[anscombe['dataset']=='IV']
fig =plt.figure()

axes1 = fig.add_subplot(2,2,1) #figure도화지 , axes축, axis여러개 축 
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

# %%
axes1.plot(d1['x'],d1['y'], 'o')
axes2.plot(d2['x'],d2['y'], 'o')
axes3.plot(d3['x'],d3['y'], 'o')
axes4.plot(d4['x'],d4['y'], 'o')

axes1.set_title('data1')
axes2.set_title('data1')
axes3.set_title('data1')
axes4.set_title('data1')

fig.tight_layout() #여백 
fig
#EDA ... 데이터 처리..
#feature engineering
#기존변수로 새로운 변수를 생성(파생변수) 
tt =sns.load_dataset('titanic')
tt.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
# 특이값(outliers) = (q3-q1)*1.5범위를 벗어나는수 -> 보통 제거 
tips = sns.load_dataset('tips')

# %%
sp =plt.figure()
axes1 = sp.add_subplot(1,1,1)
axes1.scatter(tips['total_bill'],tips['tip'])

# %%
df1 = pd.read_csv('/python_Pjt/data2/concat_1.csv')
df2 = pd.read_csv('/python_Pjt/data2/concat_2.csv')
df3 = pd.read_csv('/python_Pjt/data2/concat_3.csv')
df3
pd.concat([df1,df2,df3],ignore_index=True, axis=0)
# axis=0 밑에 붙이기
# axis =1 옆에 붙이기
# Out:
#       A    B    C    D
# 0    a0   b0   c0   d0
# 1    a1   b1   c1   d1
# 2    a2   b2   c2   d2
# 3    a3   b3   c3   d3
# 4    a4   b4   c4   d4
# 5    a5   b5   c5   d5
# 6    a6   b6   c6   d6
# 7    a7   b7   c7   d7
# 8    a8   b8   c8   d8
# 9    a9   b9   c9   d9
# 10  a10  b10  c10  d10
# 11  a11  b11  c11  d11

# %%
person =pd.read_csv('/python_Pjt/data2/survey_person.csv')
print(person)
print("="*50)
site = pd.read_csv('/python_Pjt/data2/survey_site.csv')
print(site)
print("="*50)
survey = pd.read_csv('/python_Pjt/data2/survey_survey.csv')
print(survey)
print("="*50)
visited = pd.read_csv('/python_Pjt/data2/survey_visited.csv')
print(visited)
print("="*50)
visitedSubset = visited.loc[[0,2,6]]
visitedSubset
# Out:
# ident   personal    family
# 0      dyer    William      Dyer
# 1        pb      Frank   Pabodie
# 2      lake   Anderson      Lake
# 3       roe  Valentina   Roerich
# 4  danforth      Frank  Danforth
# ...
#     name    lat    long
# 0   DR-1 -49.85 -128.57
# 1   DR-3 -47.15 -126.72
# 2  MSK-4 -48.87 -123.40
# ...
#     taken person quant  reading
# 0     619   dyer   rad     9.82
# 1     619   dyer   sal     0.13
# 2     622   dyer   rad     7.80
# 3     622   dyer   sal     0.09
# 4     734     pb   rad     8.41
# 5     734   lake   sal     0.05
# 6     734     pb  temp   -21.50
# 7     735     pb   rad     7.22
# 8     735    NaN   sal     0.06
# 9     735    NaN  temp   -26.00
# 10    751     pb   rad     4.35
# 11    751     pb  temp   -18.50
# 12    751   lake   sal     0.10
# 13    752   lake   rad     2.19
# 14    752   lake   sal     0.09
# 15    752   lake  temp   -16.00
# 16    752    roe   sal    41.60
# 17    837   lake   rad     1.46
# 18    837   lake   sal     0.21
# ...

# %%
site
# Out:
#     name    lat    long
# 0   DR-1 -49.85 -128.57
# 1   DR-3 -47.15 -126.72
# 2  MSK-4 -48.87 -123.40

# %%
o2oMerge =site.merge(visitedSubset, left_on='name', right_on='site')
#merge 왼쪽 site 의 열 오른쪽 visitedSubset의 열이름
o2oMerge
# Out:
#     name    lat    long  ident   site       dated
# 0   DR-1 -49.85 -128.57    619   DR-1  1927-02-08
# 1   DR-3 -47.15 -126.72    734   DR-3  1939-01-07
# 2  MSK-4 -48.87 -123.40    837  MSK-4  1932-01-14

# %%
site
#site 의 name 과 visited 의 site를 기준으로 병합
m2oMerge =site.merge(visited, left_on='name', right_on='site')
m2oMerge
# person의 ident
# survey의 person
ps = person.merge(survey, left_on='ident', right_on='person')
ps

vs = visited.merge(survey, left_on='ident', right_on='taken')
vs
# Out:
#     ident   site       dated  taken person quant  reading
# 0     619   DR-1  1927-02-08    619   dyer   rad     9.82
# 1     619   DR-1  1927-02-08    619   dyer   sal     0.13
# 2     622   DR-1  1927-02-10    622   dyer   rad     7.80
# 3     622   DR-1  1927-02-10    622   dyer   sal     0.09
# 4     734   DR-3  1939-01-07    734     pb   rad     8.41
# 5     734   DR-3  1939-01-07    734   lake   sal     0.05
# 6     734   DR-3  1939-01-07    734     pb  temp   -21.50
# 7     735   DR-3  1930-01-12    735     pb   rad     7.22
# 8     735   DR-3  1930-01-12    735    NaN   sal     0.06
# 9     735   DR-3  1930-01-12    735    NaN  temp   -26.00
# 10    751   DR-3  1930-02-26    751     pb   rad     4.35
# 11    751   DR-3  1930-02-26    751     pb  temp   -18.50
# 12    751   DR-3  1930-02-26    751   lake   sal     0.10
# 13    752   DR-3         NaN    752   lake   rad     2.19
# 14    752   DR-3         NaN    752   lake   sal     0.09
# ...

# %%
# print(ps)
# print("="*50)
# print(vs)

psvs = ps.merge(vs, left_on=['ident','taken','quant','reading'] ,right_on=['person','ident','quant','reading'])
print(psvs)
# Out:
# ident_x   personal   family  taken_x person_x quant  reading  ident_y  \
# 0     dyer    William     Dyer      619     dyer   rad     9.82      619
# 1     dyer    William     Dyer      619     dyer   sal     0.13      619
# 2     dyer    William     Dyer      622     dyer   rad     7.80      622
# 3     dyer    William     Dyer      622     dyer   sal     0.09      622
# 4       pb      Frank  Pabodie      734       pb   rad     8.41      734
# 5       pb      Frank  Pabodie      734       pb  temp   -21.50      734
# 6       pb      Frank  Pabodie      735       pb   rad     7.22      735
# 7       pb      Frank  Pabodie      751       pb   rad     4.35      751
# 8       pb      Frank  Pabodie      751       pb  temp   -18.50      751
# 9     lake   Anderson     Lake      734     lake   sal     0.05      734
# 10    lake   Anderson     Lake      751     lake   sal     0.10      751
# 11    lake   Anderson     Lake      752     lake   rad     2.19      752
# ...
