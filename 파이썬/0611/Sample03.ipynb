# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import html5lib
import time

search_key = input("좋아하는 음식을 입력해주세요 : ")
driver = webdriver.Chrome("chromedriver.exe")
driver.get("https://www.mangoplate.com/")
driver.find_element_by_id('main-search').send_keys(search_key)
driver.find_element_by_id('main-search').send_keys(Keys.RETURN)
time.sleep(1)
res = driver.page_source
soup =  BeautifulSoup(res,'html.parser')
soup.find_all()
# Out:
# '<html><head><style type="text/css">@charset "UTF-8";[ng\\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide:not(.ng-hide-animate){display:none !important;}ng\\:form{display:block;}</style>\n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n  <meta http-equiv="X-UA-Compatible" content="IE=edge">\n  <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no">\n  <meta name="format-detection" content="telephone=no">\n  <meta name="subject" content="중국집 맛집 인기 검색순위 | 맛집 추천, 망고플레이트">\n  <meta name="description" content="중국집의 맛집 검색결과는 17건 입니다. 중국집의 연관 리뷰, 메뉴, 사진, 특색, 주소, 전화번호, 영업시간 등의 정보를 망고플레이트에서 확인해보세요.">\n  <meta name="keywords" content="이화원, 123 최유강 중국집, 중국집, 팔선생, 자금성, 옛날 중국집, 송원중국집, 도원춘, 상하이중국집, 차이칭중국집">\n  <meta name="image" content="https://s3-ap-northeast-1.amazonaws.com/img.prod.mp/2976/emptyh_3.jpg">\n\n  <meta property="og:url" content="https://www.mangoplate.com/search/%EC%A4%91%EA%B5%AD%EC%A7%91">\n  <meta property="og:type" content="website">\n  <meta property="og:title" content="중국집 맛집 인기 검색순위 | 맛집 추천, 망고플레이트">\n  <meta property="og:description" content="중국집의 맛집 검색결과는 17건 입니다. 중국집의 연관 리뷰, 메뉴, 사진, 특색, 주소, 전화번호, 영업시간 등의 정보를 망고플레이트에서 확인해보세요.">\n  <meta property="og:image" content="https://s3-ap-northeast-1.amazonaws.com/img.prod.mp/2976/emptyh_3.jpg">\n\n\n\n    <link rel="next" href="https://www.mangoplate.com/search/%EC%A4%91%EA%B5%AD%EC%A7%91?page=2">\n\n  <!-- Twitter Meta -->\n<meta property="twitter:card" content="summary_large_image">\n<meta property="twitter:site" content="@MangoPlate">\n<meta property="twitter:url" content="https://www.mangoplate.com/search/%EC%A4%91%EA%B5%AD%EC%A7%91">\n<meta property="twitter:title" content="중국집 맛집 인기 검색순위 | 맛집 추천, 망고플레이트">\n<meta property="twitter:description" content="중국집의 맛집 검색결과는 17건 입니다. 중국집의 연관 리뷰, 메뉴, 사진, 특색, 주소, 전화번호, 영업시간 등의 정보를 망고플레이트에서 확인해보세요.">\n<meta property="twitter:image" content="https://s3-ap-northeast-1.amazonaws.com/img.prod.mp/2976/emptyh_3.jpg">\n\n  \n\t<meta property="fb:app_id" content="476661545693695">\n\t<meta property="al:ios:url" content="mangoplate://restaurants?search_keyword=중국집">\n\t<meta property="al:ios:app_store_id" content="628509224">\n\t<meta property="al:ios:app_name" content="MangoPlate">\n\n  <meta property="al:android:url" content="mangoplate://restaurants?search_keyword=중국집">\n\t<meta property="al:android:package" content="com.mangoplate">\n\t<meta property="al:android:app_name" content="MangoPlate">\n\n\n  <title>중국집 맛집 인기 검색순위 | 맛집 추천, 망고플레이트</title>\n\n  <link rel="stylesheet" media="screen" href="/assets/dist/search-acdbb8708322d58cde52dde065889fec2273dace17dc6d6acc38636a5b5c8efa.css">\n\n  <link rel="shortcut icon" href="/assets/favicon.ico">\n\n  <!-- Representative URL Setting-->\n  <link rel="canonical" href="https://www.mangoplate.com/search/%EC%A4%91%EA%B5%AD%EC%A7%91">\n    <link rel="alternate" href="https://www.mangoplate.com/search/%EC%A4%91%EA%B5%AD%EC%A7%91" hreflang="ko">\n    <link rel="alternate" href="https://www.mangoplate.com/en/search/%EC%A4%91%EA%B5%AD%EC%A7%91" hreflang="en">\n    <link rel="alternate" href="https://www.mangoplate.com/zh/search/%EC%A4%91%EA%B5%AD%EC%A7%91" hreflang="zh">\n\n  <link rel="amphtml" href="https://www.mangoplate.com/amp/search/%EC%A4%91%EA%B5%AD%EC%A7%91">\n  <!-- Google Adsense Script -->\n  <script src="https://www.googletagservices.com/activeview/js/current/osd.js?cb=%2Fr20100101"></script><script src="https://cdn.ampproject.org/rtv/012005262159000/amp4ads-host-v0.js"></script><script type="text/javascript" async="" src="https://d31qbv1cthcecs.cloudfront.net/atrk.js"></script><script src="https://connect.facebook.net/ko_KR/sdk.js?hash=61d1379ef8c442d489a2f744a166f82e&amp;ua=modern_es6" async="" crossorigin="anonymous"></script><script async="" src="https://www.google-analytics.com/analytics.js"></script><script async="async" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js" ...
