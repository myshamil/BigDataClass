# %%
import numpy as np 
import pandas as pd 

data =  pd.read_csv("./data/ign_game_reviews.csv")
data.iloc[0:5,:]

df = data.iloc[:,1:]
df.head()
df.loc[:5,'score']
df.columns
df.loc[:5,['score', 'release_year']]
type(df["score"])
df["score"].sum()
df["score"].mean()
df.mean()
df.mean(axis=1)
df.count()
df.describe()
df.corr()
df["score"]/2
filter = df["score"]>7
filter
df2= df[filter]
df2
df2.shape
df['platform']
filter2 = (df["score"]>7) & (df["platform"] == "Xbox 360")
df3 = df[filter2]
df3.shape
df3["score"].plot(kind="hist")
filter3 = df4 = df["platform"] == "Xbox 360"
df[filter3]
df[df["platform"] == "Xbox 360"]["score"].plot(kind="hist")
